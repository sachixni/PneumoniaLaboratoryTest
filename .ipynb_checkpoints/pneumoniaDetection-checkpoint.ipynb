# %%
# loading all the libraries and dependencies
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
train_dataset_path = 'chest_xray/chest_xray/train'
test_dataset_path = 'chest_xray/chest_xray/test'
val_dataset_path = 'chest_xray/chest_xray/val'

batch_size = 32
img_height = 128
img_width = 128

# train_ds = tf.keras.preprocessing.image_dataset_from_directory(
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_dataset_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# val_ds = tf.keras.utils.image_dataset_from_directory(
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  val_dataset_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)

# test_ds = tf.keras.utils.image_dataset_from_directory(
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_dataset_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 5216 files belonging to 2 classes.
# Found 16 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
for Class in [train_ds, val_ds, test_ds]:
    print(Class.class_names)
    
class_names = ['NORMAL', 'PNEUMONIA']
# Out:
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']
# ['NORMAL', 'PNEUMONIA']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 15))
for images, labels in train_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 128, 128, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

# data_augmentation = keras.Sequential(
#   [
#     layers.RandomFlip("horizontal",
#                       input_shape=(img_height,
#                                   img_width,
#                                   3)),
#     layers.RandomRotation(0.1),
#     layers.RandomZoom(0.1),
#   ]
# )
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip('horizontal'),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.3),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1)
]) 

model = Sequential([
  data_augmentation,
#   layers.Rescaling(1./255),
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),  
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

epochs=25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# Epoch 1/25
# 163/163 [==============================] - 87s 419ms/step - loss: 0.5227 - accuracy: 0.7588 - val_loss: 0.6644 - val_accuracy: 0.6250
# Epoch 2/25
# 163/163 [==============================] - 68s 418ms/step - loss: 0.3272 - accuracy: 0.8508 - val_loss: 0.5045 - val_accuracy: 0.8750
# Epoch 3/25
# 163/163 [==============================] - 68s 415ms/step - loss: 0.2665 - accuracy: 0.8840 - val_loss: 0.5731 - val_accuracy: 0.7500
# Epoch 4/25
# 163/163 [==============================] - 66s 403ms/step - loss: 0.2474 - accuracy: 0.8955 - val_loss: 0.9380 - val_accuracy: 0.6250
# Epoch 5/25
# 163/163 [==============================] - 69s 422ms/step - loss: 0.2208 - accuracy: 0.9126 - val_loss: 1.2925 - val_accuracy: 0.6250
# Epoch 6/25
# 163/163 [==============================] - 68s 414ms/step - loss: 0.2080 - accuracy: 0.9149 - val_loss: 1.0687 - val_accuracy: 0.6250
# Epoch 7/25
# 163/163 [==============================] - 66s 404ms/step - loss: 0.2030 - accuracy: 0.9201 - val_loss: 0.6713 - val_accuracy: 0.7500
# Epoch 8/25
# 163/163 [==============================] - 68s 416ms/step - loss: 0.1814 - accuracy: 0.9241 - val_loss: 0.5630 - val_accuracy: 0.8750
# Epoch 9/25
# 163/163 [==============================] - 68s 417ms/step - loss: 0.1855 - accuracy: 0.9268 - val_loss: 0.8241 - val_accuracy: 0.6875
# Epoch 10/25
# 163/163 [==============================] - 67s 410ms/step - loss: 0.1778 - accuracy: 0.9298 - val_loss: 0.6452 - val_accuracy: 0.7500
# Epoch 11/25
# 163/163 [==============================] - 68s 416ms/step - loss: 0.1676 - accuracy: 0.9375 - val_loss: 0.8779 - val_accuracy: 0.6875
# Epoch 12/25
# 163/163 [==============================] - 70s 427ms/step - loss: 0.1521 - accuracy: 0.9448 - val_loss: 0.9283 - val_accuracy: 0.6875
# Epoch 13/25
# 163/163 [==============================] - 68s 418ms/step - loss: 0.1630 - accuracy: 0.9358 - val_loss: 0.5623 - val_accuracy: 0.8125
# Epoch 14/25
# 163/163 [==============================] - 73s 449ms/step - loss: 0.1436 - accuracy: 0.9471 - val_loss: 0.5921 - val_accuracy: 0.7500
# Epoch 15/25
# 163/163 [==============================] - 69s 425ms/step - loss: 0.1386 - accuracy: 0.9475 - val_loss: 0.7207 - val_accuracy: 0.7500
# Epoch 16/25
# 163/163 [==============================] - 72s 443ms/step - loss: 0.1328 - accuracy: 0.9509 - val_loss: 0.6958 - val_accuracy: 0.7500
# Epoch 17/25
# 163/163 [==============================] - 69s 421ms/step - loss: 0.1196 - accuracy: 0.9546 - val_loss: 1.1553 - val_accuracy: 0.6875
# Epoch 18/25
# 163/163 [==============================] - 73s 448ms/step - loss: 0.1359 - accuracy: 0.9496 - val_loss: 0.3570 - val_accuracy: 0.8125
# Epoch 19/25
# 163/163 [==============================] - 72s 444ms/step - loss: 0.1249 - accuracy: 0.9549 - val_loss: 0.4781 - val_accuracy: 0.7500
# Epoch 20/25
# 163/163 [==============================] - 73s 448ms/step - loss: 0.1201 - accuracy: 0.9517 - val_loss: 0.5686 - val_accuracy: 0.6875
# Epoch 21/25
# 163/163 [==============================] - 70s 429ms/step - loss: 0.1206 - accuracy: 0.9534 - val_loss: 1.0549 - val_accuracy: 0.6250
# Epoch 22/25
# 163/163 [==============================] - 69s 423ms/step - loss: 0.1206 - accuracy: 0.9563 - val_loss: 0.6586 - val_accuracy: 0.6875
# Epoch 23/25
# 163/163 [==============================] - 70s 430ms/step - loss: 0.1144 - accuracy: 0.9559 - val_loss: 0.2947 - val_accuracy: 0.8750
# Epoch 24/25
# 163/163 [==============================] - 70s 427ms/step - loss: 0.1184 - accuracy: 0.9580 - val_loss: 0.4745 - val_accuracy: 0.7500
# Epoch 25/25
# 163/163 [==============================] - 67s 412ms/step - loss: 0.1181 - accuracy: 0.9561 - val_loss: 0.7958 - val_accuracy: 0.6875

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_12 (Sequential)   multiple                  0
# _________________________________________________________________
# rescaling (Rescaling)        multiple                  0
# _________________________________________________________________
# conv2d (Conv2D)              multiple                  448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 multiple                  0
# _________________________________________________________________
# conv2d_2 (Conv2D)            multiple                  18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2097280
# _________________________________________________________________
# dense_1 (Dense)              multiple                  258
# =================================================================
# Total params: 2,121,122
# Trainable params: 2,121,122
# Non-trainable params: 0
# _________________________________________________________________

# %%
img_file = './model_arch.png'

tf.keras.utils.plot_model(model, to_file=img_file, show_shapes=True, show_layer_names=True)

# %%
test_loss, test_accuracy = model.evaluate(test_ds)

print('Test loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# 20/20 [==============================] - 2s 91ms/step - loss: 0.6847 - accuracy: 0.7885
# Test loss: 0.68. Test accuracy: 78.85%
